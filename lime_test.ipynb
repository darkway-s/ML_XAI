# %% [markdown]
# # Using Lime with Pytorch

# %% [markdown]
# In this tutorial we will show how to use Lime framework with Pytorch. Specifically, we will use Lime to explain the prediction generated by one of the pretrained ImageNet models.
#
# Let's start with importing our dependencies. This code is tested with Pytorch 1.0 but should work with older versions as well.

# %%
model_name = 'resnet18'
image_file = './images_with_labels/3_n03661043_library.png'

# %%
import matplotlib.pyplot as plt
from PIL import Image
import torch.nn as nn
import numpy as np
import os, json

os.environ['KMP_DUPLICATE_LIB_OK']='TRUE'

import torch
from torchvision import models, transforms
from torch.autograd import Variable
import torch.nn.functional as F

# %% [markdown]
# Load our test image and see how it looks.

# %%
def get_image(path):
    with open(os.path.abspath(path), 'rb') as f:
        with Image.open(f) as img:
            return img.convert('RGB') 
        
img = get_image(image_file)
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# d:\Zhangchiyi\HKUST\Course\5012 Machine Learning\HA10-XAI\lime_test.ipynb 单元格 6 line 6
#       <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>         with Image.open(f) as img:
#       <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>             return img.convert('RGB')
# ----> <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> img = get_image(image_file)
#       <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> plt.imshow(img)
#
# d:\Zhangchiyi\HKUST\Course\5012 Machine Learning\HA10-XAI\lime_test.ipynb 单元格 6 line 2
#       <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> def get_image(path):
# ----> <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     with open(os.path.abspath(path), 'rb') as f:
#       <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>         with Image.open(f) as img:
#       <a href='vscode-notebook-cell:/d%3A/Zhangchiyi/HKUST/Course/5012%20Machine%20Learning/HA10-XAI/lime_test.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>             return img.convert('RGB')
#
# File d:\Anaconda\envs\tf\lib\site-packages\IPython\core\interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# OSError: [Errno 22] Invalid argument: 'd:\\Zhangchiyi\\HKUST\\Course\\5012 Machine Learning\\HA10-XAI\\images_with_labels\x03_n03661043_library.png'

# %% [markdown]
# We need to convert this image to Pytorch tensor and also apply whitening as used by our pretrained model.

# %%
# resize and take the center part of image to what our model expects
def get_input_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])       
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])    

    return transf

def get_input_tensors(img):
    transf = get_input_transform()
    # unsqeeze converts single image to batch of 1
    return transf(img).unsqueeze(0)

# %% [markdown]
# Load the pretrained model for Resnet50 available in Pytorch.

# %%
model_func = getattr(models, model_name)
model = model_func(pretrained=True)
# Out:
# d:\Anaconda\envs\tf\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\Anaconda\envs\tf\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# Load label texts for ImageNet predictions so we know what model is predicting

# %%
idx2label, cls2label, cls2idx = [], {}, {}
with open(os.path.abspath('./images_with_labels/imagenet_class_index.json'), 'r') as read_file:
    class_idx = json.load(read_file)
    idx2label = [class_idx[str(k)][1] for k in range(len(class_idx))]
    cls2label = {class_idx[str(k)][0]: class_idx[str(k)][1] for k in range(len(class_idx))}
    cls2idx = {class_idx[str(k)][0]: k for k in range(len(class_idx))}

# %% [markdown]
# Get the predicition for our image.

# %%
img_t = get_input_tensors(img)
model.eval()
logits = model(img_t)

# %% [markdown]
# Predicitions we got are logits. Let's pass that through softmax to get probabilities and class labels for top 5 predictions.

# %%
probs = F.softmax(logits, dim=1)
probs5 = probs.topk(5)
tuple((p,c, idx2label[c]) for p, c in zip(probs5[0][0].detach().numpy(), probs5[1][0].detach().numpy()))
# Out:
# ((0.77625877, 575, 'golfcart'),
#  (0.061075244, 428, 'barrow'),
#  (0.031032942, 559, 'folding_chair'),
#  (0.017262388, 670, 'motor_scooter'),
#  (0.009628274, 703, 'park_bench'))

# %% [markdown]
# We are getting ready to use Lime. Lime produces the array of images from original input image by pertubation algorithm. So we need to provide two things: (1) original image as numpy array (2) classification function that would take array of purturbed images as input and produce the probabilities for each class for each image as output.
#
# For Pytorch, first we need to define two separate transforms: (1) to take PIL image, resize and crop it (2) take resized, cropped image and apply whitening.

# %%
def get_pil_transform(): 
    transf = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.CenterCrop(224)
    ])    

    return transf

def get_preprocess_transform():
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                    std=[0.229, 0.224, 0.225])     
    transf = transforms.Compose([
        transforms.ToTensor(),
        normalize
    ])    

    return transf    

pill_transf = get_pil_transform()
preprocess_transform = get_preprocess_transform()

# %% [markdown]
# Now we are ready to define classification function that Lime needs. The input to this function is numpy array of images where each image is ndarray of shape (channel, height, width). The output is numpy aaray of shape (image index, classes) where each value in array should be probability for that image, class combination.

# %%
def batch_predict(images):
    model.eval()
    batch = torch.stack(tuple(preprocess_transform(i) for i in images), dim=0)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    batch = batch.to(device)
    
    logits = model(batch)
    probs = F.softmax(logits, dim=1)
    return probs.detach().cpu().numpy()

# %% [markdown]
# Let's test our function for the sample image.

# %%
test_pred = batch_predict([pill_transf(img)])
test_pred.squeeze().argmax()
# Out:
# 575

# %% [markdown]
# Import lime and create explanation for this prediciton.

# %%
from lime import lime_image

# %%
explainer = lime_image.LimeImageExplainer()
explanation = explainer.explain_instance(np.array(pill_transf(img)), 
                                         batch_predict, # classification function
                                         top_labels=5, 
                                         hide_color=0, 
                                         num_samples=1000) # number of images that will be sent to classification function
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Let's use mask on image and see the areas that are encouraging the top prediction.

# %%
from skimage.segmentation import mark_boundaries

# %%
topk = 5

# %%
temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=2, hide_rest=True)
img_boundry1 = mark_boundaries(temp/255.0, mask)
plt.imshow(img_boundry1)

# %% [markdown]
# Let's turn on areas that contributes against the top prediction.

# %%
topk = 2

temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=topk, hide_rest=False)
img_boundry2 = mark_boundaries(temp/255.0, mask)

# add title to the image, title = predicted class name + model_name

title_name = '%s-%s-top%s' % (idx2label[test_pred.squeeze().argmax()],
                         model_name, topk)
plt.title(title_name)
plt.imshow(img_boundry2)
